# %% [markdown]
# <a href="https://colab.research.google.com/github/augustinevmomo/ML-With-Python-Bootcamp/blob/main/ML_Bootcamp_weekend_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1\ Part one

# %%
Liberia = 1847
print(Liberia)     # output: 1847
print("Liberia")   # output: Liberia
# Explanation:
# print(Liberia) print the value stored in the variable (1847)
# print ("Liberia") print the text "Liberia" because it is string
# Out:
# 1847
# Liberia

# %% [markdown]
# Problem 2

# %%
country = "Liberia"

print(country)
print(country, "became independent in", 1847)
# Out:
# Liberia
# Liberia became independent in 1847

# %% [markdown]
# Problem 3

# %%
print('The year is "1847"')
# Out:
# The year is "1847"

# %% [markdown]
# Problem 4/ part two

# %%
market_name = "Gobachop Market"
total_market_table = 150
price_per_bag = 3200.50
is_market_open = True

print("Market name:", market_name)
print("Total tables:", total_market_table)
print("price per bag:", price_per_bag)
print("Is market open:", is_market_open)
# Out:
# Market name: Gobachop Market
# Total tables: 150
# price per bag: 3200.5
# Is market open: True

# %%
current_price = 2550.75
quantity = 10

total_cost = current_price * quantity

print("Total cost for 10 bags:", total_cost, "LRD")
# Out:
# Total cost for 10 bags: 25507.5 LRD

# %% [markdown]
# Problem 6

# %%
has_scarcity = False
is_rainy = True

print("Scarcity today:", has_scarcity)
print("Rainy today:", is_rainy)
# Out:
# Scarcity today: False
# Rainy today: True

# %% [markdown]
# Problem 7\ part 3

# %%
price_per_bag = 800
quantity = 25

total_revenue = price_per_bag *quantity

print("Total revenue:", total_revenue, "LRD")
# Out:
# Total revenue: 20000 LRD

# %% [markdown]
# Problem 8

# %%
today_price = 3200
increase = 150

tomorrow_price = today_price + increase

print("Tomorrow's Price:", tomorrow_price, "LRD")
# Out:
# Tomorrow's Price: 3350 LRD

# %% [markdown]
# Problem 9

# %%
cost = 1800
traders = 3

cost_per_trader = cost / traders

print("Cost per trader:", cost_per_trader, "LRD")
# Out:
# Cost per trader: 600.0 LRD

# %% [markdown]
# Problem 10

# %%
original_price = 2500
discount_rate = 0.10

discount_amount = original_price * discount_rate
final_price = original_price - discount_amount

print("Discount amount:", discount_amount, "LRD")
print("Final price:", final_price, "LRD")
# Out:
# Discount amount: 250.0 LRD
# Final price: 2250.0 LRD

# %% [markdown]
# Problem 11\ part4

# %%
item = "cassava"
price = 800

print(item)    # cassava
print("item")  # item
print(price)   # 800
print("price") # price

# Explanation:
# item is a variable 'n it stores
"cassava"
# "item" is just 'n python prints it exactly as written
# Out:
# cassava
# item
# 800
# price
# 'cassava'

# %% [markdown]
# Problem 12

# %%
product = "pepper"
cost = 150.50

print("one bags of:", product, "costs", cost, "LRD")
# Out:
# one bags of: pepper costs 150.5 LRD
